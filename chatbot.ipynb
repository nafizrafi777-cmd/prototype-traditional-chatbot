# %% [markdown]
# # Prototype Simple Traditional Chatbot Project
#
# **Course:** AI-HCI
#
# **Student:** Nafiz Ahmed Rafi
#
# **Week:** Week 3
#
# This notebook demonstrates the implementation of a simple rule-based chatbot using traditional (non-LLM) techniques.

# %% [markdown]
# # Project Objective
#
# The objective of this project is to design and implement a simple traditional chatbot using Python. The chatbot follows a rule-based approach in which predefined user questions are matched with predefined responses.
#
# This project demonstrates:
#
# - Traditional chatbot architecture
# - Rule-based conversational systems
# - Human-Computer Interaction (HCI) principles
# - Basic software development lifecycle
# - User interaction through a command-line interface
#
# Unlike modern AI chatbots that rely on Large Language Models (LLMs), this chatbot provides responses only to questions that have been explicitly programmed into its knowledge base.

# %%
# ---------------------------------------------------------
# Prototype Simple Traditional Chatbot
# AI-HCI Week 3
# Author: Nafiz Ahmed Rafi
#
# This chatbot uses a rule-based approach rather than a
# Large Language Model (LLM). Responses are selected from
# predefined rules using conditional statements.
# ---------------------------------------------------------

print("===========================================")
print(" Welcome to the Traditional Chatbot ")
print("===========================================")
print("Type 'bye' anytime to exit the chatbot.\n")
# Out:
# ...
#  Welcome to the Traditional Chatbot
# ...
# Type 'bye' anytime to exit the chatbot.

# %% [markdown]
# # Chatbot Knowledge Base
#
# The chatbot knowledge base consists of a Python dictionary containing predefined user questions and corresponding responses. Whenever the user enters a supported question, the chatbot searches the dictionary and returns the associated response.
#
# This approach represents a traditional rule-based chatbot where responses are manually programmed instead of being generated dynamically by an Artificial Intelligence model.

# %%
# ----------------------------------------------------------
# Main Chatbot Program
# ----------------------------------------------------------

while True:
    user_input = input("You: ").lower().strip()

    if user_input == "bye":
        print("Chatbot:", responses["bye"])
        break

    elif user_input in responses:
        print("Chatbot:", responses[user_input])

    else:
        print("Chatbot: Sorry, I don't understand that question.")
# Out:
# You: hello
# Chatbot: Hello! Nice to meet you.
# You: what is ai
# Chatbot: Artificial Intelligence enables computers to perform tasks that usually require human intelligence.
# You: what is hci
# Chatbot: Human-Computer Interaction studies how people interact with computers and technology.
# You: thank you
# Chatbot: You're welcome!
# You: bye
# Chatbot: Goodbye! Have a wonderful day!

# %% [markdown]
# # Testing and Results
# The chatbot was tested using multiple predefined user inputs to verify that the conversation logic functioned correctly.
#
# The following questions were tested successfully:
#
# - hello
# - what is ai
# - what is hci
# - thank you
# - bye
#
# The chatbot correctly matched each predefined question with its corresponding response and terminated successfully when the user entered "bye." The testing confirmed that the rule-based logic performed as expected.

# %% [markdown]
# # Chatbot Development Lifecycle
#
# The development of this traditional chatbot followed a simple software development lifecycle consisting of the following stages:
#
# ## 1. Requirements Analysis
# The objective was to build a simple rule-based chatbot capable of answering predefined questions without using Large Language Models (LLMs).
#
# ## 2. Design
# A dictionary-based knowledge base was selected to store user questions and chatbot responses. Conditional statements were used to control the conversation flow.
#
# ## 3. Implementation
# The chatbot was implemented using Python in Google Colab. A loop continuously accepted user input, searched the predefined responses, and displayed the appropriate answer.
#
# ## 4. Testing
# The chatbot was tested using several sample questions such as:
# - hello
# - what is ai
# - what is hci
# - thank you
# - bye
#
# Testing confirmed that predefined responses were returned correctly and the chatbot terminated properly when the user entered "bye."
#
# ## 5. Maintenance
# Additional responses can easily be added to the dictionary to improve the chatbot's capabilities. Future versions could include sentiment analysis, Azure AI services, or natural language processing.

# %% [markdown]
# # Lessons Learned
#
# Through this project, I learned how traditional chatbots differ from modern AI-powered chatbots.
#
# Traditional chatbots rely on predefined rules and conditional logic, making them predictable and efficient for answering frequently asked questions. However, they cannot understand complex language or answer questions that were not programmed into the knowledge base.
#
# This project also demonstrated the importance of Human-Computer Interaction (HCI). A chatbot should provide clear prompts, understandable responses, and consistent interaction so that users can easily communicate with the system.

# %% [markdown]
# # Future Improvements
#
# Several enhancements could improve this chatbot in future versions:
#
# - Integrate Microsoft Azure AI Language Services.
# - Perform sentiment analysis on user messages.
# - Support Natural Language Processing (NLP).
# - Store conversation history.
# - Develop a graphical user interface using Gradio or Streamlit.
# - Expand the chatbot knowledge base with additional topics.
# - Deploy the chatbot as a web application.
